# %%
#1:1人脸对比
#!/usr/bin/env python
#coding=utf-8

from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.CompareFaceRequest import CompareFaceRequest

client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')
request = CompareFaceRequest()
request.set_accept_format('json')

request.set_ImageURLA("http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/968deb76-f558-40ef-8b42-5ba85a2ee515.jpg")
request.set_ImageURLB("http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/e22e77ab-22ce-42c2-adf0-dbf7673e8623.jpg")

response = client.do_action_with_exception(request)
# python2:  print(response) 
print(str(response, encoding='utf-8'))
# Out:
# {"RequestId":"D75C9A3A-2A90-4D5B-A869-B997DEF3C961","Data":{"Thresholds":[61.0,69.0,75.0],"Confidence":0.0,"RectAList":[189,70,102,137],"RectBList":[49,30,47,66]}}

# %%
#url转化
from viapi.fileutils import FileUtils
import ssl
file_utils = FileUtils("LTAI4FzUqzex9go7H9pDujtc","R9SZBiPsGNoamZ9SJv6umDoQqG2SSY")
oss_url = file_utils.get_oss_url("C:/Users/Administrator/Desktop/12/wangjianlin.jpg","jpg",True)
print(oss_url)
oss_url = file_utils.get_oss_url("C:/Users/Administrator/Desktop/12/aobama.jpg","jpg",True)
print(oss_url)
# Out:
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/968deb76-f558-40ef-8b42-5ba85a2ee515.jpg
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/e22e77ab-22ce-42c2-adf0-dbf7673e8623.jpg

# %%
#创建人脸识别库
from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.CreateFaceDbRequest import CreateFaceDbRequest
client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')
request = CreateFaceDbRequest()
request.set_accept_format('json')
request.set_Name("cycxclct")
response = client.do_action_with_exception(request)
# python2:  print(response) 
print(str(response, encoding='utf-8'))

# %%
#添加单个人脸
from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.AddFaceRequest import AddFaceRequest

client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')

request = AddFaceRequest()
request.set_accept_format('json')

request.set_DbName("cycxclct")
request.set_ImageUrl("http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/e22e77ab-22ce-42c2-adf0-dbf7673e8623.jpg")
request.set_EntityId("01")
request.set_ExtraData("奥巴马")

response = client.do_action_with_exception(request)
# python2:  print(response) 
print(str(response, encoding='utf-8'))
# Out:
# {"RequestId":"AC50CC6C-ED17-4A49-A287-0A028CCF7D65","Data":{"FaceId":"1591586361668000"}}

# %%
###添加人脸

from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.AddFaceRequest import AddFaceRequest
from viapi.fileutils import FileUtils
import ssl
file_utils = FileUtils("LTAI4FzUqzex9go7H9pDujtc","R9SZBiPsGNoamZ9SJv6umDoQqG2SSY")

client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')
request = AddFaceRequest()
request.set_accept_format('json')

for fname in glob.glob("C:/Users/Administrator/Desktop/face/base1/*.jpg",recursive=True):
    print(fname)
    ExtraData=(fname.split('/')[-1])
    ExtraData=ExtraData[6:].replace(".jpg","")
    print(ExtraData)
    oss_url = file_utils.get_oss_url(fname,"jpg",True)
    request.set_DbName("cycxclct")
    request.set_ImageUrl(oss_url)
    #request.set_EntityId("01")
    request.set_ExtraData(ExtraData)
    try:
        response = client.do_action_with_exception(request)
# python2:  print(response) 
    except:
        pass
    print(str(response, encoding='utf-8'))
# Out:
# C:/Users/Administrator/Desktop/face/base1\baojie-1.jpg
# baojie-1
# {"RequestId":"DBB663C4-83AA-408B-839F-15735BD7E82F","Data":{"FaceId":"1591587173161000"}}
# C:/Users/Administrator/Desktop/face/base1\gaoge-1.jpg
# gaoge-1
# {"RequestId":"DBB663C4-83AA-408B-839F-15735BD7E82F","Data":{"FaceId":"1591587173161000"}}
# C:/Users/Administrator/Desktop/face/base1\gaoge-2.jpg
# gaoge-2
# {"RequestId":"DBB663C4-83AA-408B-839F-15735BD7E82F","Data":{"FaceId":"1591587173161000"}}
# C:/Users/Administrator/Desktop/face/base1\kecheng-000.jpg
# kecheng-000
# {"RequestId":"DBB663C4-83AA-408B-839F-15735BD7E82F","Data":{"FaceId":"1591587173161000"}}
# C:/Users/Administrator/Desktop/face/base1\kecheng-001.jpg
# kecheng-001
# {"RequestId":"DBB663C4-83AA-408B-839F-15735BD7E82F","Data":{"FaceId":"1591587173161000"}}
# C:/Users/Administrator/Desktop/face/base1\kecheng-002.jpg
# kecheng-002
# {"RequestId":"DBB663C4-83AA-408B-839F-15735BD7E82F","Data":{"FaceId":"1591587173161000"}}
# ...

# %%
#添加人脸样本库24个
from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.AddFaceEntityRequest import AddFaceEntityRequest

client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')

request = AddFaceEntityRequest()
request.set_accept_format('json')

request.set_DbName("cycxclct")
for i in  range(0,65):
    request.set_EntityId(str(i))
    response = client.do_action_with_exception(request)
# python2:  print(response) 
    #print(str(response, encoding='utf-8'))
    print("第%d个成功"% i)
# Out:
# 第0个成功
# 第1个成功
# 第2个成功
# 第3个成功
# 第4个成功
# 第5个成功
# 第6个成功
# 第7个成功
# 第8个成功
# 第9个成功
# 第10个成功
# 第11个成功
# 第12个成功
# 第13个成功
# 第14个成功
# 第15个成功
# 第16个成功
# 第17个成功
# 第18个成功
# 第19个成功
# 第20个成功
# 第21个成功
# 第22个成功
# 第23个成功
# 第24个成功
# 第25个成功
# 第26个成功
# 第27个成功
# 第28个成功
# 第29个成功
# 第30个成功
# 第31个成功
# 第32个成功
# 第33个成功
# 第34个成功
# 第35个成功
# 第36个成功
# 第37个成功
# 第38个成功
# 第39个成功
# 第40个成功
# 第41个成功
# 第42个成功
# 第43个成功
# 第44个成功
# 第45个成功
# 第46个成功
# 第47个成功
# 第48个成功
# 第49个成功
# 第50个成功
# 第51个成功
# 第52个成功
# 第53个成功
# 第54个成功
# 第55个成功
# 第56个成功
# 第57个成功
# 第58个成功
# 第59个成功
# 第60个成功
# 第61个成功
# 第62个成功
# 第63个成功
# 第64个成功

# %%
#添加大量人脸，因每个entity限制5个，for循环
from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.AddFaceRequest import AddFaceRequest
from viapi.fileutils import FileUtils
import ssl
import time
file_utils = FileUtils("LTAI4FzUqzex9go7H9pDujtc","R9SZBiPsGNoamZ9SJv6umDoQqG2SSY")
client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')
request = AddFaceRequest()
request.set_accept_format('json')
i=0
k=0
for fname in glob.glob("C:/Users/Administrator/Desktop/face/base1/*.jpg",recursive=True):
    i=i+1
    print("第 %d 张图片" % i)
    #rint(fname)
    ExtraData=(fname.split('/')[-1])
    ExtraData=ExtraData[6:].replace(".jpg","")
    print(ExtraData)
    oss_url = file_utils.get_oss_url(fname,"jpg",True)
    print(oss_url)
    request.set_DbName("cycxclct")
    request.set_ImageUrl(oss_url) 
    request.set_EntityId(str(k))
    request.set_ExtraData(ExtraData)
    try:
        time.sleep(1)
        response = client.do_action_with_exception(request)
        print("第 %d 个entityID" % k)
        print(str(response, encoding='utf-8'))
    except:
        pass
    if((i%5) == 0):
        k += 1
# Out:
# 第 1 张图片
# baojie-1
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/18ca52a0-4c22-49f2-96ee-19ee85f57043.jpg
# 第 0 个entityID
# {"RequestId":"848DFC2A-006F-4076-BA71-866F086DA751","Data":{"FaceId":"1591603097339000"}}
# 第 2 张图片
# gaoge-1
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/653458a5-b8cb-4437-9e7f-be29d0399147.jpg
# 第 3 张图片
# gaoge-2
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/bf667873-6eb2-4b17-b9bd-a5d03a5b6d56.jpg
# 第 4 张图片
# kecheng-000
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/6dde74ab-6fc3-4c4f-98e5-9f425a15fa18.jpg
# 第 0 个entityID
# {"RequestId":"65E6CBC0-2556-4AD6-84A3-7C523C3B7766","Data":{"FaceId":"1591603102271000"}}
# 第 5 张图片
# kecheng-001
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/bfe99759-c1d9-47e1-b84e-e4843cf5089a.jpg
# 第 0 个entityID
# ...

# %%
#删除人脸样本库
from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.DeleteFaceEntityRequest import DeleteFaceEntityRequest

client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')

request = DeleteFaceEntityRequest()
request.set_accept_format('json')

request.set_DbName("cycxclct")
for i in  range(0,3):
    request.set_EntityId(str(i))
    response = client.do_action_with_exception(request)
# python2:  print(response) 
    #print(str(response, encoding='utf-8'))
# Out:
# ---------------------------------------------------------------------------
# ServerException                           Traceback (most recent call last)
# <ipython-input-24-3943711e38d9> in <module>
#      13 for i in  range(0,3):
#      14     request.set_EntityId(str(i))
# ---> 15     response = client.do_action_with_exception(request)
#      16 # python2:  print(response)
#      17     #print(str(response, encoding='utf-8'))
#
# d:\python\python37\lib\site-packages\aliyunsdkcore\client.py in do_action_with_exception(self, acs_request)
#     465
#     466         if exception:
# --> 467             raise exception
#     468         logger.debug('Response received. Product:%s Response-body: %s',
#     469                      acs_request.get_product(), body)
#
# ServerException: HTTP Status: 400 Error:InvalidParameter.BadRequest 人脸样本不存在 RequestID: D6C661CA-C9DF-4FEE-9203-BF1B9DA36EF8

# %%
##识别人脸
#!/usr/bin/env python
#coding=utf-8
import re
from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.SearchFaceRequest import SearchFaceRequest
from viapi.fileutils import FileUtils
import ssl
file_utils = FileUtils("LTAI4FzUqzex9go7H9pDujtc","R9SZBiPsGNoamZ9SJv6umDoQqG2SSY")
client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')
request = SearchFaceRequest()
request.set_accept_format('json')
request.set_DbName("cycxclct")
#oss_url = file_utils.get_oss_url("C:/Users/Administrator/Desktop/12/wangjianlin.jpg","jpg",True)
#print(oss_url)
for fname in glob.glob("C:/Users/Administrator/Desktop/202006/*.jpg",recursive=True):
    #i=i+1
    #print("第 %d 张图片" % i)
    #rint(fname)
    #ExtraData=(fname.split('/')[-1])
    #ExtraData=ExtraData[6:].replace(".jpg","")
    #print(ExtraData)
    oss_url = file_utils.get_oss_url(fname,"jpg",True)
    print(oss_url)
    request.set_ImageUrl(oss_url)
    request.set_Limit(1)
    try:
        response = client.do_action_with_exception(request)
# python2:  print(response) 
        print(type(response))
        #response =response["Data"]
        print(str(response, encoding='utf-8')[131:185])  #["MatchList"][0]["FaceItems"][0]
    except:
         pass
        #re.findall(r"a(.+?)b", str)
# Out:
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/35273e0a-1b0e-4137-b952-701fe42f9450.jpg
# <class 'bytes'>
# ,"Score":0.7620031124549994,"ExtraData":"zhangge-047"}
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/86d79246-939f-4ce1-8c2e-7476471d208d.jpg
# <class 'bytes'>
# ,"Score":1.0,"ExtraData":"zhangge-000"}],"Location":{"
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/0aaa03a1-8c16-4dee-ad3b-25c3057de1aa.jpg
# <class 'bytes'>
# ,"Score":0.7197497348419528,"ExtraData":"song-3"}],"Lo
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/0a7d85bd-9b5e-4dd7-9781-bfd003bab9b0.jpg
# <class 'bytes'>
# ,"Score":0.7789716600469594,"ExtraData":"tao-3"}],"Loc
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/2fca67a8-c5da-46b3-9717-ec9ee5e618e1.jpg
# <class 'bytes'>
# "Score":0.5496316057142571,"ExtraData":"kecheng-020"}]
# ...

# %%
{"RequestId":"E104385E-6F1F-4DBC-95E9-D4BD27A63EE1","Data":{"MatchList":[{"FaceItems":[{"FaceId":"1591603319744000","EntityId":"26","Score":0.7620031124549994,"ExtraData":"zhangge-047"}],"Location":{"X":62,"Y":55,"Height":33,"Width":23}}]}}

# %%
#添加人脸样本库24个
from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.AddFaceEntityRequest import AddFaceEntityRequest

client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')

request = AddFaceEntityRequest()
request.set_accept_format('json')

request.set_DbName("cycxclct")
for i in  range(0,3):
    request.set_EntityId(str(i))
    response = client.do_action_with_exception(request)
# python2:  print(response) 
    #print(str(response, encoding='utf-8'))
    print("第%d个成功"% i)
# Out:
# 第0个成功
# 第1个成功
# 第2个成功

# %%
###添加人脸

from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.AddFaceRequest import AddFaceRequest
from viapi.fileutils import FileUtils
import ssl
import glob
file_utils = FileUtils("LTAI4FzUqzex9go7H9pDujtc","R9SZBiPsGNoamZ9SJv6umDoQqG2SSY")

client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')
request = AddFaceRequest()
request.set_accept_format('json')

for fname in glob.glob("C:/Users/Administrator/Desktop/face/p/*.jpg",recursive=True):
    print(fname)
    ExtraData=(fname.split('/')[-1])
    #ExtraData=ExtraData[6:].replace(".jpg","")
    #print(ExtraData)
    oss_url = file_utils.get_oss_url(fname,"jpg",True)
    request.set_DbName("cycxclct")
    request.set_ImageUrl(oss_url)
    request.set_EntityId("0")
    request.set_ExtraData(ExtraData)
    try:
        response = client.do_action_with_exception(request)
# python2:  print(response) 
    except:
        pass
    print(str(response, encoding='utf-8'))
# Out:
# C:/Users/Administrator/Desktop/face/p\pengcheng-004.jpg
# {"RequestId":"C91EDAA1-CFEE-4DBF-9A95-9C246B3E6660","Data":{"FaceId":"1591690537839000"}}
# C:/Users/Administrator/Desktop/face/p\pengcheng-005.jpg
# {"RequestId":"F4D47CD2-F534-4164-B844-D1BB3C321827","Data":{"FaceId":"1591690538510000"}}
# C:/Users/Administrator/Desktop/face/p\pengcheng-006.jpg
# {"RequestId":"A77A3484-15E9-45D7-A12E-0B97E02C1F9F","Data":{"FaceId":"1591690539137000"}}
# C:/Users/Administrator/Desktop/face/p\pengcheng-034.jpg
# {"RequestId":"204D07AD-6AF4-4E87-ACB7-906A78080936","Data":{"FaceId":"1591690539836000"}}
# C:/Users/Administrator/Desktop/face/p\pengcheng-037.jpg
# {"RequestId":"38E60EE7-A822-4AA5-9AFA-E8305194C9C9","Data":{"FaceId":"1591690540534000"}}
# C:/Users/Administrator/Desktop/face/p\pengcheng-5.jpg
# {"RequestId":"38E60EE7-A822-4AA5-9AFA-E8305194C9C9","Data":{"FaceId":"1591690540534000"}}
# C:/Users/Administrator/Desktop/face/p\pengcheng-7.jpg
# ...

# %%
from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.AddFaceRequest import AddFaceRequest
from viapi.fileutils import FileUtils
import ssl
import time
file_utils = FileUtils("LTAI4FzUqzex9go7H9pDujtc","R9SZBiPsGNoamZ9SJv6umDoQqG2SSY")
client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')
request = AddFaceRequest()
request.set_accept_format('json')
i=0
k=0
for fname in glob.glob("C:/Users/Administrator/Desktop/face/base1/*.jpg",recursive=True):
    i=i+1
    print("第 %d 张图片" % i)
    #rint(fname)
    ExtraData=(fname.split('/')[-1])
    ExtraData=ExtraData[6:].replace(".jpg","")
    print(ExtraData)
    oss_url = file_utils.get_oss_url(fname,"jpg",True)
    print(oss_url)
    request.set_DbName("cycxclct")
    request.set_ImageUrl(oss_url) 
    request.set_EntityId(str(k))
    request.set_ExtraData(ExtraData)
    try:
        time.sleep(1)
        response = client.do_action_with_exception(request)
        print("第 %d 个entityID" % k)
        print(str(response, encoding='utf-8'))
    except:
        pass
    if((i%5) == 0):
        k += 1
# Out:
# 第 1 张图片
# baojie-1
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/c2a21792-c7ec-4a3f-9af4-da82d1eec4dc.jpg
# 第 2 张图片
# gaoge-1
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/ac1ff725-f508-4ca7-be37-b7a9983964c1.jpg
# 第 3 张图片
# gaoge-2
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/e0e89b0c-2e51-4e9e-803f-90cc2ddfe45e.jpg
# 第 4 张图片
# kecheng-000
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/17619fac-fe00-45ef-9ddc-eeb89769bfc6.jpg
# 第 5 张图片
# kecheng-001
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/a4125331-84cc-47f6-893b-ec549c2d3895.jpg
# 第 6 张图片
# kecheng-002
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/b3021623-d52d-41a2-9aed-2287725b5556.jpg
# 第 1 个entityID
# {"RequestId":"7D170C75-4434-466D-A47A-6E75B7AC9753","Data":{"FaceId":"1591690553879000"}}
# 第 7 张图片
# ...

# %%
##识别人脸
#!/usr/bin/env python
#coding=utf-8
import re
from aliyunsdkcore.client import AcsClient
from aliyunsdkcore.acs_exception.exceptions import ClientException
from aliyunsdkcore.acs_exception.exceptions import ServerException
from aliyunsdkfacebody.request.v20191230.SearchFaceRequest import SearchFaceRequest
from viapi.fileutils import FileUtils
import ssl
file_utils = FileUtils("LTAI4FzUqzex9go7H9pDujtc","R9SZBiPsGNoamZ9SJv6umDoQqG2SSY")
client = AcsClient('LTAI4FzUqzex9go7H9pDujtc', 'R9SZBiPsGNoamZ9SJv6umDoQqG2SSY', 'cn-shanghai')
request = SearchFaceRequest()
request.set_accept_format('json')
request.set_DbName("cycxclct")
#oss_url = file_utils.get_oss_url("C:/Users/Administrator/Desktop/12/wangjianlin.jpg","jpg",True)
#print(oss_url)
for fname in glob.glob("C:/Users/Administrator/Desktop/test/*.jpg",recursive=True):
    #i=i+1
    #print("第 %d 张图片" % i)
    #rint(fname)
    #ExtraData=(fname.split('/')[-1])
    #ExtraData=ExtraData[6:].replace(".jpg","")
    #print(ExtraData)
    oss_url = file_utils.get_oss_url(fname,"jpg",True)
    print(oss_url)
    request.set_ImageUrl(oss_url)
    request.set_Limit(1)
    try:
        response = client.do_action_with_exception(request)
# python2:  print(response) 
        #print(type(response))
        #response =response["Data"]
        print(str(response, encoding='utf-8')[131:185])  #["MatchList"][0]["FaceItems"][0]
    except:
         pass
        #re.findall(r"a(.+?)b", str)
# Out:
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/1c54c8d2-814e-4338-8344-9b63580ee65f.jpg
# "Score":-0.3285262959838555,"ExtraData":"p\\pengcheng-
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/4e9f06dc-bca0-4d41-89f3-fb31cc138dc6.jpg
# "Score":-0.5342053444154287,"ExtraData":"kecheng-003"}
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/3c9da7d3-f276-4ef4-8634-88e0a2eb3286.jpg
# "Score":1.0,"ExtraData":"kecheng-002"}],"Location":{"X
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/c515d902-746b-46ee-b126-558c5a192897.jpg
# "Score":1.0,"ExtraData":"kecheng-003"}],"Location":{"X
# http://viapi-customer-temp.oss-cn-shanghai.aliyuncs.com/LTAI4FzUqzex9go7H9pDujtc/671637b0-1b1f-48e9-b5e7-977187037b4d.jpg
# "Score":0.5393873771686084,"ExtraData":"k\\kecheng-9.j
# ...
